# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report,accuracy_score
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.max_columns', 30)
data = pd.read_csv('kidneyChronic.csv', na_values=["?"]);
data.head()
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv  wbcc rbcc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane class
# 0   no   ckd
# 1   no   ckd
# 2  yes   ckd
# 3  yes   ckd
# 4   no   ckd

# %%
data.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# min      1.500000    0.400000    4.500000    2.500000    3.100000
# 25%     27.000000    0.900000  135.000000    3.800000   10.300000
# 50%     42.000000    1.300000  138.000000    4.400000   12.650000
# 75%     66.000000    2.800000  142.000000    4.900000   15.000000
# max    391.000000   76.000000  163.000000   47.000000   17.800000

# %%
data.isnull().sum()
# Out:
# age        9
# bp        12
# sg        47
# al        46
# su        49
# rbc      152
# pc        65
# pcc        4
# ba         4
# bgr       44
# bu        19
# sc        17
# sod       87
# pot       88
# hemo      52
# pcv       70
# wbcc     105
# rbcc     130
# htn        2
# dm         2
# cad        2
# appet      1
# pe         1
# ane        1
# class      0
# dtype: int64

# %%
# numerical columns
num_cols = ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

# %%
cate_cols = data.columns.drop('class').drop(num_cols)
cate_cols
# Out:
# Index(['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'], dtype='object')

# %%
X = data.iloc[:, 0:24].values
y = data.iloc[:, 24].values

# %%
from sklearn.impute import SimpleImputer
imp_numerical = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_numerical = imp_numerical.fit(X[:, 0:5])
X[:, 0:5] = imp_numerical.transform(X[:, 0:5])

imp_numerical1 = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_numerical1 = imp_numerical1.fit(X[:, 9:15])
X[:, 9:15] = imp_numerical1.transform(X[:, 9:15])

imp_categorical = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_categorical = imp_numerical.fit(X[:, 5:9])
X[:, 5:9] = imp_numerical.transform(X[:, 5:9])

imp_categorical = imp_numerical.fit(X[:, 9:23])
X[:, 9:23] = imp_numerical.transform(X[:, 9:23])

dff = pd.DataFrame({'age' :X[:,0], 'bp':X[:,1],'sg':X[:,2],'al':X[:,3],'su':X[:,4],'rbc':X[:,5]
                    ,'pc':X[:,6],'pcc':X[:,7],'ba':X[:,8],'bgr':X[:,9],'bu':X[:,10],'sc':X[:,11]
                    ,'sod':X[:,12],'pot':X[:,13],'hemo':X[:,14],'pcv':X[:,15],'wbcc':X[:,16],'rbcc':X[:,17]
                    ,'htn':X[:,18],'dm':X[:,19],'cad':X[:,20],'appet':X[:,21],'pe':X[:,22],'ane':X[:,23]})

dff
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 0    48   80   1.02  1  0    normal    normal  notpresent  notpresent  121
# 1     7   50   1.02  4  0    normal    normal  notpresent  notpresent   99
# 2    62   80   1.01  2  3    normal    normal  notpresent  notpresent  423
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4    51   80   1.01  2  0    normal    normal  notpresent  notpresent  106
# 5    60   90  1.015  3  0    normal    normal  notpresent  notpresent   74
# 6    68   70   1.01  0  0    normal    normal  notpresent  notpresent  100
# 7    24   80  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8    52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9    53   90   1.02  2  0  abnormal  abnormal     present  notpresent   70
# 10   50   60   1.01  2  4    normal  abnormal     present  notpresent  490
# 11   63   70   1.01  3  0  abnormal  abnormal     present  notpresent  380
# 12   68   70  1.015  3  1    normal    normal     present  notpresent  208
# 13   68   70   1.02  0  0    normal    normal  notpresent  notpresent   98
# 14   68   80   1.01  3  2    normal  abnormal     present     present  157
# 15   40   80  1.015  3  0    normal    normal  notpresent  notpresent   76
# 16   47   70  1.015  2  0    normal    normal  notpresent  notpresent   99
# 17   47   80   1.02  0  0    normal    normal  notpresent  notpresent  114
# 18   60  100  1.025  0  3    normal    normal  notpresent  notpresent  263
# 19   62   60  1.015  1  0    normal  abnormal     present  notpresent  100
# 20   61   80  1.015  2  0  abnormal  abnormal  notpresent  notpresent  173
# 21   60   90   1.02  0  0    normal    normal  notpresent  notpresent   99
# 22   48   80  1.025  4  0    normal  abnormal  notpresent  notpresent   95
# 23   21   70   1.01  0  0    normal    normal  notpresent  notpresent   99
# 24   42  100  1.015  4  0    normal  abnormal  notpresent     present   99
# 25   61   60  1.025  0  0    normal    normal  notpresent  notpresent  108
# 26   75   80  1.015  0  0    normal    normal  notpresent  notpresent  156
# 27   69   70   1.01  3  4    normal  abnormal  notpresent  notpresent  264
# 28   75   70   1.02  1  3    normal    normal  notpresent  notpresent  123
# 29   68   70  1.005  1  0  abnormal  abnormal     present  notpresent   99
# ..   ..  ...    ... .. ..       ...       ...         ...         ...  ...
# 370  69   70   1.02  0  0    normal    normal  notpresent  notpresent   83
# 371  28   60  1.025  0  0    normal    normal  notpresent  notpresent   79
# 372  72   60   1.02  0  0    normal    normal  notpresent  notpresent  109
# 373  61   70  1.025  0  0    normal    normal  notpresent  notpresent  133
# 374  79   80  1.025  0  0    normal    normal  notpresent  notpresent  111
# 375  70   80   1.02  0  0    normal    normal  notpresent  notpresent   74
# 376  58   70  1.025  0  0    normal    normal  notpresent  notpresent   88
# 377  64   70   1.02  0  0    normal    normal  notpresent  notpresent   97
# 378  71   60  1.025  0  0    normal    normal  notpresent  notpresent   99
# 379  62   80  1.025  0  0    normal    normal  notpresent  notpresent   78
# 380  59   60   1.02  0  0    normal    normal  notpresent  notpresent  113
# 381  71   70  1.025  0  0    normal    normal  notpresent  notpresent   79
# 382  48   80  1.025  0  0    normal    normal  notpresent  notpresent   75
# 383  80   80  1.025  0  0    normal    normal  notpresent  notpresent  119
# 384  57   60   1.02  0  0    normal    normal  notpresent  notpresent  132
# 385  63   70   1.02  0  0    normal    normal  notpresent  notpresent  113
# 386  46   70  1.025  0  0    normal    normal  notpresent  notpresent  100
# 387  15   80  1.025  0  0    normal    normal  notpresent  notpresent   93
# 388  51   80   1.02  0  0    normal    normal  notpresent  notpresent   94
# 389  41   80  1.025  0  0    normal    normal  notpresent  notpresent  112
# 390  52   80  1.025  0  0    normal    normal  notpresent  notpresent   99
# 391  36   80  1.025  0  0    normal    normal  notpresent  notpresent   85
# 392  57   80   1.02  0  0    normal    normal  notpresent  notpresent  133
# 393  43   60  1.025  0  0    normal    normal  notpresent  notpresent  117
# 394  50   80   1.02  0  0    normal    normal  notpresent  notpresent  137
# 395  55   80   1.02  0  0    normal    normal  notpresent  notpresent  140
# 396  42   70  1.025  0  0    normal    normal  notpresent  notpresent   75
# 397  12   80   1.02  0  0    normal    normal  notpresent  notpresent  100
# 398  17   60  1.025  0  0    normal    normal  notpresent  notpresent  114
# 399  58   80  1.025  0  0    normal    normal  notpresent  notpresent  131
#
#       bu   sc  sod  pot  hemo pcv   wbcc rbcc  htn   dm  cad appet   pe  ane
# 0     36  1.2  135  3.5  15.4  44   7800  5.2  yes  yes   no  good   no   no
# 1     18  0.8  135  3.5  11.3  38   6000  5.2   no   no   no  good   no   no
# 2     53  1.8  135  3.5   9.6  31   7500  5.2   no  yes   no  poor   no  yes
# 3     56  3.8  111  2.5  11.2  32   6700  3.9  yes   no   no  poor  yes  yes
# 4     26  1.4  135  3.5  11.6  35   7300  4.6   no   no   no  good   no   no
# 5     25  1.1  142  3.2  12.2  39   7800  4.4  yes  yes   no  good  yes   no
# 6     54   24  104    4  12.4  36   9800  5.2   no   no   no  good   no   no
# 7     31  1.1  135  3.5  12.4  44   6900    5   no  yes   no  good  yes   no
# 8     60  1.9  135  3.5  10.8  33   9600    4  yes  yes   no  good   no  yes
# 9    107  7.2  114  3.7   9.5  29  12100  3.7  yes  yes   no  poor   no  yes
# 10    55    4  135  3.5   9.4  28   9800  5.2  yes  yes   no  good   no  yes
# 11    60  2.7  131  4.2  10.8  32   4500  3.8  yes  yes   no  poor  yes   no
# 12    72  2.1  138  5.8   9.7  28  12200  3.4  yes  yes  yes  poor  yes   no
# 13    86  4.6  135  3.4   9.8  41   9800  5.2  yes  yes  yes  poor  yes   no
# 14    90  4.1  130  6.4   5.6  16  11000  2.6  yes  yes  yes  poor  yes   no
# 15   162  9.6  141  4.9   7.6  24   3800  2.8  yes   no   no  good   no  yes
# 16    46  2.2  138  4.1  12.6  41   9800  5.2   no   no   no  good   no   no
# 17    87  5.2  139  3.7  12.1  41   9800  5.2  yes   no   no  poor   no   no
# 18    27  1.3  135  4.3  12.7  37  11400  4.3  yes  yes  yes  good   no   no
# 19    31  1.6  135  3.5  10.3  30   5300  3.7  yes   no  yes  good   no   no
# 20   148  3.9  135  5.2   7.7  24   9200  3.2  yes  yes  yes  poor  yes  yes
# 21   180   76  4.5  3.5  10.9  32   6200  3.6  yes  yes  yes  good   no   no
